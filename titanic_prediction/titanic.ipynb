# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv("titanic.csv")
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
columns = ["Name", "Ticket", "Fare", "Cabin"]
dataset.drop(columns=columns, inplace=True)
dataset.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0            1         0       3    male  22.0      1      0        S
# 1            2         1       1  female  38.0      1      0        C
# 2            3         1       3  female  26.0      0      0        S
# 3            4         1       1  female  35.0      1      0        S
# 4            5         0       3    male  35.0      0      0        S

# %%
dataset.drop(columns=["PassengerId"], inplace=True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Embarked  889 non-null    object
# dtypes: float64(1), int64(4), object(2)
# memory usage: 48.9+ KB

# %%
# Numerical_cols = ["Pclass", "Age", "SibSp", "Parch"]
# categorical_cols = ["Sex", "Embarked"]

# feature_cols = []
# for col in categorical_cols:
#     vocab = dataset[col].unique()
#     feature_cols.append(tf.feature_column.categorical_columns_with_vocabulary_list(col, vocab))
# for col in Numerical_cols:
#     feature_cols.append(tf.numeric_columns(col, dtype=tf.float))

# Standardize Age (mean = 0, std = 1)
dataset["Age"].fillna(dataset["Age"].mean(), inplace=True)
dataset["Age"] = (dataset["Age"] - dataset["Age"].mean()) / dataset["Age"].std()
dataset.head()
# Out:
#    Survived  Pclass     Sex       Age  SibSp  Parch Embarked
# 0         0       3    male -0.592148      1      0        S
# 1         1       1  female  0.638430      1      0        C
# 2         1       3  female -0.284503      0      0        S
# 3         1       1  female  0.407697      1      0        S
# 4         0       3    male  0.407697      0      0        S

# %%
dataset["Embarked"].fillna(dataset["Embarked"].mode()[0], inplace=True)
dataset.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10992\334343710.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Embarked"].fillna(dataset["Embarked"].mode()[0], inplace=True)
#    Survived  Pclass     Sex       Age  SibSp  Parch Embarked
# 0         0       3    male -0.592148      1      0        S
# 1         1       1  female  0.638430      1      0        C
# 2         1       3  female -0.284503      0      0        S
# 3         1       1  female  0.407697      1      0        S
# 4         0       3    male  0.407697      0      0        S

# %%
sex = {
    "male" : 1,
    "female" : 0
}
embarked = {
    "S" : 0,
    "C" : 1,
    "Q" : 2
}
dataset["Sex"] = dataset["Sex"].map(sex)
dataset["Embarked"] = dataset["Embarked"].map(embarked)
dataset.head()
# Out:
#    Survived  Pclass  Sex       Age  SibSp  Parch  Embarked
# 0         0       3    1 -0.592148      1      0         0
# 1         1       1    0  0.638430      1      0         1
# 2         1       3    0 -0.284503      0      0         0
# 3         1       1    0  0.407697      1      0         0
# 4         0       3    1  0.407697      0      0         0

# %%
target = dataset.pop("Survived")

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(16, activation="relu", input_shape=(6,)),
    tf.keras.layers.Dense(16, activation="relu"),
    tf.keras.layers.Dense(1, activation="sigmoid")
])
# Out:
# C:\Users\user\Documents\Ra_Ma_Dan\myenv\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"]
)

# %%
x_train, x_test, y_train, y_test = train_test_split(dataset, target, random_state=42, test_size=.25)
x_train
# Out:
#      Pclass  Sex           Age  SibSp  Parch  Embarked
# 298       1    1 -1.553581e-18      0      0         0
# 884       3    1 -3.614146e-01      0      0         0
# 247       2    0 -4.383257e-01      0      2         0
# 478       3    1 -5.921480e-01      0      0         0
# 305       1    1 -2.213435e+00      1      2         0
# ..      ...  ...           ...    ...    ...       ...
# 106       3    0 -6.690592e-01      0      0         0
# 270       1    1 -1.553581e-18      0      0         0
# 860       3    1  8.691639e-01      2      0         0
# 435       1    0 -1.207437e+00      1      2         0
# 102       1    1 -6.690592e-01      0      1         0
#
# [668 rows x 6 columns]

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

model.fit(
    x_train, y_train,
    epochs=40,
    batch_size=32,
    validation_split=0.20
)
# Out:
# Epoch 1/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8316 - loss: 0.3800 - val_accuracy: 0.8209 - val_loss: 0.4200
# Epoch 2/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8341 - loss: 0.4018 - val_accuracy: 0.8209 - val_loss: 0.4188
# Epoch 3/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8526 - loss: 0.3773 - val_accuracy: 0.8358 - val_loss: 0.4160
# Epoch 4/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8302 - loss: 0.3990 - val_accuracy: 0.8209 - val_loss: 0.4190
# Epoch 5/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8281 - loss: 0.3790 - val_accuracy: 0.8284 - val_loss: 0.4160
# Epoch 6/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8575 - loss: 0.3623 - val_accuracy: 0.8209 - val_loss: 0.4190
# Epoch 7/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8498 - loss: 0.3834 - val_accuracy: 0.8209 - val_loss: 0.4186
# Epoch 8/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8408 - loss: 0.3846 - val_accuracy: 0.8209 - val_loss: 0.4166
# Epoch 9/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8483 - loss: 0.3947 - val_accuracy: 0.8209 - val_loss: 0.4230
# Epoch 10/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8383 - loss: 0.4023 - val_accuracy: 0.8284 - val_loss: 0.4180
# Epoch 11/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8104 - loss: 0.4137 - val_accuracy: 0.8284 - val_loss: 0.4224
# Epoch 12/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7979 - loss: 0.4255 - val_accuracy: 0.8284 - val_loss: 0.4172
# Epoch 13/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8332 - loss: 0.4082 - val_accuracy: 0.8358 - val_loss: 0.4174
# Epoch 14/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8229 - loss: 0.4194 - val_accuracy: 0.8284 - val_loss: 0.4178
# Epoch 15/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8224 - loss: 0.4199 - val_accuracy: 0.8358 - val_loss: 0.4202
# Epoch 16/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8325 - loss: 0.4086 - val_accuracy: 0.8284 - val_loss: 0.4173
# Epoch 17/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8349 - loss: 0.4022 - val_accuracy: 0.8284 - val_loss: 0.4215
# Epoch 18/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8354 - loss: 0.4033 - val_accuracy: 0.8209 - val_loss: 0.4215
# Epoch 19/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8189 - loss: 0.4148 - val_accuracy: 0.8284 - val_loss: 0.4200
# Epoch 20/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8105 - loss: 0.4191 - val_accuracy: 0.8209 - val_loss: 0.4209
# Epoch 21/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8201 - loss: 0.4191 - val_accuracy: 0.8284 - val_loss: 0.4237
# Epoch 22/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8541 - loss: 0.3649 - val_accuracy: 0.8284 - val_loss: 0.4191
# Epoch 23/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8630 - loss: 0.3401 - val_accuracy: 0.8358 - val_loss: 0.4212
# Epoch 24/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8502 - loss: 0.3753 - val_accuracy: 0.8358 - val_loss: 0.4232
# Epoch 25/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8560 - loss: 0.3612 - val_accuracy: 0.8358 - val_loss: 0.4218
# Epoch 26/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8254 - loss: 0.4025 - val_accuracy: 0.8134 - val_loss: 0.4187
# Epoch 27/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8507 - loss: 0.3648 - val_accuracy: 0.8284 - val_loss: 0.4254
# Epoch 28/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8477 - loss: 0.3670 - val_accuracy: 0.8358 - val_loss: 0.4207
# Epoch 29/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8434 - loss: 0.3761 - val_accuracy: 0.8358 - val_loss: 0.4239
# Epoch 30/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8369 - loss: 0.3845 - val_accuracy: 0.8284 - val_loss: 0.4210
# Epoch 31/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8285 - loss: 0.3937 - val_accuracy: 0.8284 - val_loss: 0.4257
# Epoch 32/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8220 - loss: 0.4010 - val_accuracy: 0.8209 - val_loss: 0.4191
# Epoch 33/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8382 - loss: 0.3865 - val_accuracy: 0.8284 - val_loss: 0.4265
# Epoch 34/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8589 - loss: 0.3550 - val_accuracy: 0.8209 - val_loss: 0.4190
# Epoch 35/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8460 - loss: 0.3722 - val_accuracy: 0.8284 - val_loss: 0.4210
# Epoch 36/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8443 - loss: 0.3831 - val_accuracy: 0.8134 - val_loss: 0.4199
# Epoch 37/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8301 - loss: 0.4065 - val_accuracy: 0.8284 - val_loss: 0.4295
# Epoch 38/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8149 - loss: 0.3995 - val_accuracy: 0.8284 - val_loss: 0.4241
# Epoch 39/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8431 - loss: 0.3695 - val_accuracy: 0.8358 - val_loss: 0.4229
# Epoch 40/40
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8193 - loss: 0.4057 - val_accuracy: 0.8358 - val_loss: 0.4229

# %%
train_loss, train_acc = model.evaluate(x_train, y_train)
print(f"Train Acc: {train_acc * 100:.2f}%\nTrain Loss: {train_loss * 100:.2f}%")
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8436 - loss: 0.3772
# Train Acc: 83.53%
# Train Loss: 39.27%

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test Acc: {test_acc * 100:.2f}%\nTest Loss: {test_loss * 100:.2f}%")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7984 - loss: 0.4332
# Test Acc: 80.27%
# Test Loss: 43.80%
